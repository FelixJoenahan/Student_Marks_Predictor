# %% [markdown]
# <a href="https://colab.research.google.com/github/FelixJoenahan/Student_Marks_Predictor/blob/main/Python_Notebook_1_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python For Machine Learning**

# %% [markdown]
# Python language has standard features like other programming languages i.e. Data Structures, Loops etc.  However, for machine leaning, we may not need this standard syntax.
#
# First of all, we need to learn about **Python Libraries**.
#
# # **What is a Python library?**
# Python libraries are collections of modules that contain useful codes and functions, eliminating the need to write them from scratch.
#
# Today, we will learn about a very important library called **Pandas** which is heavily used in Data Science and Machine Learning.

# %% [markdown]
# **Syntax to import a library:**
#
# We use import [library name] e.g. **import pandas**
#
# We can use aliases/shortnames e.g. **import pandas as pd**
#
# NOTE: If a library is not available, we install it. The most common way is **pip install [library name]**

# %%
# Your code here to import pandas library to your file
import pandas as pd

# %% [markdown]
# # **Load Dataset**
#
# Dataset can be loaded from local machine or a server.
#
# It can be loaded from various file formats too e.g. Excel, JSON, CSV.
#
# To load a CSV:
#
# pandas.read_csv("CSV FILE NAME")
# pd.read_csv("CSV FILE NAME")
#
# Here, we will load dataset from local machine. You should have **titanic.csv** (from Canvas) and upload to your Jupyter server.

# %%
# your code to load csv file
data = pd.read_csv("titanic.csv")

# %% [markdown]
# The **data** vartiable in the statement above reads data from a csv file and converts into a **DataFrame**. A DataFrame is a two dimensional data structure i.e. rows and columns. Now try to use following methods to see top 5, 10 and bottom 5 rows from the dataset
#
# data.head()
#
# data.head(10)
#
# data.tail()

# %%
# TRY YOUR CODE HERE
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# **data.info()** lets us see the information of all features in the dataset i.e. their names, number of non-null values, and data types

# %%
# TRY YOUR CODE HERE
# Write your observation from this information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Now, let's try **data.describe()**. It lets us see some useful statistics for the data e.g. min and max values. This code gives us several statistics for the data. Not all may be useful for one dataset.

# %%
# TRY YOUR CODE HERE
# Write your observation from this information e.g. what observation you made for Survived feature
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Access Individual Features
#
# Try following
#
# data["Column Name"]
#
# data[1:3]    (Change range and observe the difference)
#
# data.iloc[1:5, 3:4]  (Observe the data, make changes)
#
# data.iloc[2:15, 1:2]   (range_of_rows, range_of_columns)

# %%
# TRY YOUR CODE HERE
# Write your observation
data["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data[1:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
data.iloc[1:5, 3:4]  #data.iloc[row_range, column_range]
# Out:
#                                                 Name
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %% [markdown]
# # Exercise 1:
#
# **value_counts()** function counts different categories in a column/feature. Write code to check how many survived or did not survived as per the dataset.

# %%
# YOUR CODE GOES HERE
data["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Exercise 2:
#
# It is a brainstormer exercise. **data.dropna()** will drop all rows with NULL values.
#
# Use this method  **data.dropna()** and then try to print **data.inof()**
#
# Now use  **data = data.dropna()** and then try to print **data.inof()**
#
# What differnece you have noticed? Do you think, it is a good idea to use dropna()? If not, why not?

# %%
# Write your observations
data = data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int64
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    object
#  4   Sex          183 non-null    object
#  5   Age          183 non-null    float64
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    object
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 18.6+ KB

# %% [markdown]
# # Exercise 3:
#
# **data.drop(['COLUMN_1', 'COLUMN_2'], axis=1, inplace= True)** drops the unwanted columns. Re-run the code from first cell, ignoring Exercise 2 (so that you have full dataset agaian). Now look at the data and see which columns/features you feel won't add any value to the dataset outputs. Drop those columns and check **data.info()**.  You can try this code with or without inplace parameter.

# %%
# YOUR CODE
data.drop(['Name', 'Ticket'], axis=1, inplace= True)

# %% [markdown]
# # Plotting
#
# Let's try some plotting methods using **Pandas**

# %%
# use histograms to see data frequencies
data.hist()
# Out:
# array([[<Axes: title={'center': 'PassengerId'}>,
#         <Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Fare'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
# Folloing code shows how many different values we have in Survived column i.e. how many survived and how many did not survied
data["Survived"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Exercise 4:
#
# Plot data from Age to see what different age ranges were travelling on the ship

# %%
# Your Code Here
data["Age"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Exercise 5:
#
# Now Try to plot how many Male or Female travellers were on board.

# %%
# Your Code goes here
data["Sex"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# If you get error while plotting the above since data is not numeric, you will need to convert column into numeric values. one way of doing this is using **numpy** library.
#
# import numpy as np
#
# data["Sex"] = np.where(data["Sex"] == "female", 0, 1)

# %%
# Your Code goes here
data.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.931818
# male      0.431579
# Name: Survived, dtype: float64

# %% [markdown]
# # Congratulations! - You have completed Lab 1

# %% [markdown]
# ## Author

# %% [markdown]
# [Arooj Fatima](https://www.aru.ac.uk/people/arooj-fatima)
